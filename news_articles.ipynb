# %%
import pandas as pd
import numpy as np


prices = pd.read_csv("data/upload_DJIA_table.csv")
prices['Date'] = pd.to_datetime(prices['Date'])
prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1989 entries, 0 to 1988
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1989 non-null   datetime64[ns]
#  1   Open       1989 non-null   float64
#  2   High       1989 non-null   float64
#  3   Low        1989 non-null   float64
#  4   Close      1989 non-null   float64
#  5   Volume     1989 non-null   int64
#  6   Adj Close  1989 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 108.9 KB

# %%
prices.set_index('Date', inplace=True)

# %%
prices.loc['2015']
# Out:
#                     Open          High           Low         Close     Volume  \
# Date
# 2015-12-31  17590.660156  17590.660156  17421.160156  17425.029297   93690000
# 2015-12-30  17711.939453  17714.130859  17588.869141  17603.869141   59760000
# 2015-12-29  17547.369141  17750.019531  17547.369141  17720.980469   69860000
# 2015-12-28  17535.660156  17536.900391  17437.339844  17528.269531   59770000
# 2015-12-24  17593.259766  17606.339844  17543.949219  17552.169922   40350000
# ...                  ...           ...           ...           ...        ...
# 2015-01-08  17591.970703  17916.039062  17591.970703  17907.869141  114890000
# 2015-01-07  17374.779297  17597.080078  17374.779297  17584.519531   91030000
# 2015-01-06  17504.179688  17581.050781  17262.369141  17371.640625  101870000
# 2015-01-05  17821.300781  17821.300781  17475.929688  17501.650391  116160000
# 2015-01-02  17823.070312  17951.779297  17731.300781  17832.990234   76270000
#
#                Adj Close
# ...

# %%
from matplotlib import pyplot as plt



prices['Open'].plot(title='Dow Jones Stock Price')

plt.tight_layout()
plt.grid()
plt.show()

# %%
prices[['Open']].plot(subplots=True)
# Out:
# array([<AxesSubplot:xlabel='Date'>], dtype=object)

# %%
prices.asfreq('M')['Open'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
prices.sort_index().loc['2010-1':'2012-1']
# Out:
#                     Open          High           Low         Close     Volume  \
# Date
# 2010-01-04  10430.690430  10604.969727  10430.690430  10583.959961  179780000
# 2010-01-05  10584.559570  10584.559570  10522.519531  10572.019531  188540000
# 2010-01-06  10564.719727  10594.990234  10546.549805  10573.679688  186040000
# 2010-01-07  10571.110352  10612.370117  10505.209961  10606.860352  217390000
# 2010-01-08  10606.400391  10619.400391  10554.330078  10618.190430  172710000
# ...                  ...           ...           ...           ...        ...
# 2012-01-25  12673.629883  12778.259766  12580.120117  12758.849609  135430000
# 2012-01-26  12756.959961  12841.950195  12695.160156  12734.629883  130840000
# 2012-01-27  12733.950195  12733.950195  12630.719727  12660.459961  164410000
# 2012-01-30  12659.169922  12659.320312  12529.410156  12653.719727  130430000
# 2012-01-31  12654.780273  12720.099609  12567.330078  12632.910156  168070000
#
#                Adj Close
# ...

# %%
prices.sort_index().loc['2010-07-10' : '2012-07-10', :]
# Out:
#                     Open          High           Low         Close     Volume  \
# Date
# 2010-07-12  10199.240234  10220.280273  10146.490234  10216.269531  131490000
# 2010-07-13  10217.549805  10407.820312  10217.549805  10363.019531  179040000
# 2010-07-14  10370.959961  10400.099609  10303.000000  10366.719727  208530000
# 2010-07-15  10367.099609  10379.740234  10240.480469  10359.309570  210000000
# 2010-07-16  10356.200195  10356.200195  10079.580078  10097.900391  335060000
# ...                  ...           ...           ...           ...        ...
# 2012-07-03  12868.059570  12946.200195  12845.280273  12943.660156   63850000
# 2012-07-05  12941.849609  12961.299805  12852.240234  12896.669922   97800000
# 2012-07-06  12889.400391  12889.400391  12702.990234  12772.469727   96760000
# 2012-07-09  12772.019531  12772.019531  12686.570312  12736.290039  100150000
# 2012-07-10  12733.870117  12830.290039  12606.910156  12653.120117  114760000
#
#                Adj Close
# ...

# %%
prices.asfreq('B')
# Out:
#                     Open          High           Low         Close  \
# Date
# 2008-08-08  11432.089844  11759.959961  11388.040039  11734.320312
# 2008-08-11  11729.669922  11867.110352  11675.530273  11782.349609
# 2008-08-12  11781.700195  11782.349609  11601.519531  11642.469727
# 2008-08-13  11632.809570  11633.780273  11453.339844  11532.959961
# 2008-08-14  11532.070312  11718.280273  11450.889648  11615.929688
# ...                  ...           ...           ...           ...
# 2016-06-27  17355.210938  17355.210938  17063.080078  17140.240234
# 2016-06-28  17190.509766  17409.720703  17190.509766  17409.720703
# 2016-06-29  17456.019531  17704.509766  17456.019531  17694.679688
# 2016-06-30  17712.759766  17930.609375  17711.800781  17929.990234
# 2016-07-01  17924.240234  18002.380859  17916.910156  17949.369141
#
#                  Volume     Adj Close
# Date
# 2008-08-08  212830000.0  11734.320312
# 2008-08-11  183190000.0  11782.349609
# ...

# %%
prices.loc['2012', ['Open']].reset_index(drop=True)
# Out:
#              Open
# 0    12938.190430
# 1    13095.080078
# 2    13114.969727
# 3    13138.849609
# 4    13190.150391
# ..            ...
# 245  12359.309570
# 246  12407.450195
# 247  12418.419922
# 248  12392.459961
# 249  12221.190430
#
# [250 rows x 1 columns]

# %%
import pandas as pd
# Import data here
prices = pd.read_csv('data/upload_DJIA_table.csv', parse_dates=['Date'], index_col='Date')

prices.head()
# Out:
#                     Open          High           Low         Close     Volume  \
# Date
# 2016-07-01  17924.240234  18002.380859  17916.910156  17949.369141   82160000
# 2016-06-30  17712.759766  17930.609375  17711.800781  17929.990234  133030000
# 2016-06-29  17456.019531  17704.509766  17456.019531  17694.679688  106380000
# 2016-06-28  17190.509766  17409.720703  17190.509766  17409.720703  112190000
# 2016-06-27  17355.210938  17355.210938  17063.080078  17140.240234  138740000
#
#                Adj Close
# Date
# 2016-07-01  17949.369141
# 2016-06-30  17929.990234
# 2016-06-29  17694.679688
# 2016-06-28  17409.720703
# 2016-06-27  17140.240234

# %%
prices.loc['2015':]
# Out:
# /var/folders/7y/57xm51hj4y11r4hg1s330bth0000gn/T/ipykernel_17024/1363710813.py:1: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   prices.loc['2015':]
#                     Open          High           Low         Close     Volume  \
# Date
# 2016-07-01  17924.240234  18002.380859  17916.910156  17949.369141   82160000
# 2016-06-30  17712.759766  17930.609375  17711.800781  17929.990234  133030000
# 2016-06-29  17456.019531  17704.509766  17456.019531  17694.679688  106380000
# 2016-06-28  17190.509766  17409.720703  17190.509766  17409.720703  112190000
# 2016-06-27  17355.210938  17355.210938  17063.080078  17140.240234  138740000
# ...                  ...           ...           ...           ...        ...
# 2015-01-08  17591.970703  17916.039062  17591.970703  17907.869141  114890000
# 2015-01-07  17374.779297  17597.080078  17374.779297  17584.519531   91030000
# ...

# %%
prices.sort_index().loc['2015':]
# Out:
#                     Open          High           Low         Close     Volume  \
# Date
# 2015-01-02  17823.070312  17951.779297  17731.300781  17832.990234   76270000
# 2015-01-05  17821.300781  17821.300781  17475.929688  17501.650391  116160000
# 2015-01-06  17504.179688  17581.050781  17262.369141  17371.640625  101870000
# 2015-01-07  17374.779297  17597.080078  17374.779297  17584.519531   91030000
# 2015-01-08  17591.970703  17916.039062  17591.970703  17907.869141  114890000
# ...                  ...           ...           ...           ...        ...
# 2016-06-27  17355.210938  17355.210938  17063.080078  17140.240234  138740000
# 2016-06-28  17190.509766  17409.720703  17190.509766  17409.720703  112190000
# 2016-06-29  17456.019531  17704.509766  17456.019531  17694.679688  106380000
# 2016-06-30  17712.759766  17930.609375  17711.800781  17929.990234  133030000
# 2016-07-01  17924.240234  18002.380859  17916.910156  17949.369141   82160000
#
#                Adj Close
# ...

# %%
# Set data frequency to business daily
prices = prices.asfreq('B')

# Create 'lagged' and 'shifted'
prices['lagged'] = prices['Close'].shift(-90)
prices['shifted'] = prices['Close'].shift(90)

# Plot the google price series
prices[['Close', 'lagged', 'shifted']].plot(subplots=True)
plt.show()

# %%
prices.asfreq('Y')
# Out:
#                     Open          High           Low         Close  \
# Date
# 2008-12-31   8666.480469   8842.660156   8664.889648   8776.389648
# 2009-12-31  10548.509766  10555.009766  10423.129883  10428.049805
# 2010-12-31  11569.330078  11597.410156  11530.320312  11577.509766
# 2011-12-31           NaN           NaN           NaN           NaN
# 2012-12-31  12938.190430  13109.129883  12883.889648  13104.139648
# 2013-12-31  16512.380859  16588.250000  16511.480469  16576.660156
# 2014-12-31  17987.660156  18043.220703  17820.880859  17823.070312
# 2015-12-31  17590.660156  17590.660156  17421.160156  17425.029297
#
#                  Volume     Adj Close        lagged       shifted
# Date
# 2008-12-31  226760000.0   8776.389648   8512.280273  11502.509766
# 2009-12-31  137940000.0  10428.049805  10520.320312   9580.629883
# 2010-12-31   93330000.0  11577.509766  12638.740234  10150.650391
# 2011-12-31          NaN           NaN           NaN           NaN
# ...

# %% [markdown]
# ![image.png](attachment:d2a8966d-6a36-4487-a4c4-829310bc0c5c.png)

# %% [markdown]
# ![image.png](attachment:34bb7059-3400-4dfd-860e-fbc80a47cc18.png)

# %% [markdown]
# ![image.png](attachment:eb8f4157-fc61-466a-8b1e-f86f534c0ba0.png)
